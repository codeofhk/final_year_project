# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-abd877da-6341-4e26-8b17-dd3d76a1fd35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abd877da-6341-4e26-8b17-dd3d76a1fd35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#    perc []  percw []  Freq [GHz]  dB(S(FloquetPort1:1,FloquetPort1:1)) []  \
# 0      2.5       2.5        0.10                               -40.110703
# 1      2.5       2.5        0.11                               -39.283096
# 2      2.5       2.5        0.12                               -38.527553
# 3      2.5       2.5        0.13                               -37.832529
# 4      2.5       2.5        0.14                               -37.189050
#
#    dB(S(FloquetPort2:1,FloquetPort1:1)) []
# 0                                -0.001776
# 1                                -0.001917
# 2                                -0.002070
# 3                                -0.002237
# 4                                -0.002417

# %%
data.describe()
# Out:
#              perc []       percw []     Freq [GHz]  \
# count  503723.000000  503723.000000  503723.000000
# mean       13.444664      13.444664      10.050000
# std         7.140252       7.140252       5.747527
# min         2.500000       2.500000       0.100000
# 25%         7.000000       7.000000       5.070000
# 50%        13.000000      13.000000      10.050000
# 75%        20.000000      20.000000      15.030000
# max        25.000000      25.000000      20.000000
#
#        dB(S(FloquetPort1:1,FloquetPort1:1)) []  \
# count                            503723.000000
# mean                                 -6.973686
# std                                   6.239289
# min                                 -42.078049
# 25%                                 -11.812572
# 50%                                  -5.382000
# 75%                                  -1.196231
# max                                  -0.024098
#
#        dB(S(FloquetPort2:1,FloquetPort1:1)) []
# ...

# %%
data.isna().count()
# Out:
# perc []                                    503723
# percw []                                   503723
# Freq [GHz]                                 503723
# dB(S(FloquetPort1:1,FloquetPort1:1)) []    503723
# dB(S(FloquetPort2:1,FloquetPort1:1)) []    503723
# dtype: int64

# %%
data.dropna()
# Out:
#         perc []  percw []  Freq [GHz]  \
# 0           2.5       2.5        0.10
# 1           2.5       2.5        0.11
# 2           2.5       2.5        0.12
# 3           2.5       2.5        0.13
# 4           2.5       2.5        0.14
# ...         ...       ...         ...
# 503718     25.0      25.0       19.96
# 503719     25.0      25.0       19.97
# 503720     25.0      25.0       19.98
# 503721     25.0      25.0       19.99
# 503722     25.0      25.0       20.00
#
#         dB(S(FloquetPort1:1,FloquetPort1:1)) []  \
# 0                                    -40.110703
# 1                                    -39.283096
# 2                                    -38.527553
# 3                                    -37.832529
# 4                                    -37.189050
# ...                                         ...
# 503718                                -9.790397
# 503719                                -9.775824
# 503720                                -9.761314
# ...

# %%
X = data.iloc[:, 2:]
X
# Out:
#         Freq [GHz]  dB(S(FloquetPort1:1,FloquetPort1:1)) []  \
# 0             0.10                               -40.110703
# 1             0.11                               -39.283096
# 2             0.12                               -38.527553
# 3             0.13                               -37.832529
# 4             0.14                               -37.189050
# ...            ...                                      ...
# 503718       19.96                                -9.790397
# 503719       19.97                                -9.775824
# 503720       19.98                                -9.761314
# 503721       19.99                                -9.746868
# 503722       20.00                                -9.732484
#
#         dB(S(FloquetPort2:1,FloquetPort1:1)) []
# 0                                     -0.001776
# 1                                     -0.001917
# 2                                     -0.002070
# 3                                     -0.002237
# ...

# %%
X['perc []'].value_counts()
# Out:
# 2.5     37829
# 15.0    37829
# 25.0    37829
# 5.0     37829
# 7.0     25883
# 9.0     25883
# 11.0    25883
# 3.0     25883
# 17.0    25883
# 19.0    25883
# 21.0    25883
# 23.0    25883
# 13.0    25883
# 7.5     19910
# 10.0    19910
# 12.5    19910
# 17.5    19910
# 20.0    19910
# 22.5    19910
# Name: perc [], dtype: int64

# %%
y = data.iloc[:, :2]
y
# Out:
#         perc []  percw []
# 0           2.5       2.5
# 1           2.5       2.5
# 2           2.5       2.5
# 3           2.5       2.5
# 4           2.5       2.5
# ...         ...       ...
# 503718     25.0      25.0
# 503719     25.0      25.0
# 503720     25.0      25.0
# 503721     25.0      25.0
# 503722     25.0      25.0
#
# [503723 rows x 2 columns]

# %%
X = X.drop(columns=['dB(S(FloquetPort1:1,FloquetPort1:1)) []'])
X
# Out:
#         Freq [GHz]  dB(S(FloquetPort2:1,FloquetPort1:1)) []
# 0             0.10                                -0.001776
# 1             0.11                                -0.001917
# 2             0.12                                -0.002070
# 3             0.13                                -0.002237
# 4             0.14                                -0.002417
# ...            ...                                      ...
# 503718       19.96                                -0.626374
# 503719       19.97                                -0.628238
# 503720       19.98                                -0.630111
# 503721       19.99                                -0.631991
# 503722       20.00                                -0.633878
#
# [503723 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42 )

# %%
X_train
# Out:
#         Freq [GHz]  dB(S(FloquetPort2:1,FloquetPort1:1)) []
# 379968       16.88                                -0.441440
# 276958        2.19                                -2.976827
# 324174       16.42                                -0.558670
# 26108         2.35                                -0.188053
# 132840       14.44                                -0.424781
# ...            ...                                      ...
# 259178        3.58                                -8.308688
# 365838       14.95                                -0.215628
# 131932        5.36                                -9.823866
# 146867       15.34                                -0.227265
# 121958        5.17                               -11.307687
#
# [428164 rows x 2 columns]

# %%
X_test
# Out:
#         Freq [GHz]  dB(S(FloquetPort2:1,FloquetPort1:1)) []
# 245810        9.27                                -4.991611
# 261104        2.93                                -5.089830
# 341289        8.38                                -2.784448
# 286334       16.31                                -0.368396
# 454068        1.30                                -1.607708
# ...            ...                                      ...
# 496723        9.74                                -0.917399
# 327594       10.80                                -0.550308
# 92968        13.92                                -0.241845
# 264198       13.96                                -0.165863
# 208961       19.07                                -1.568133
#
# [75559 rows x 2 columns]

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(hidden_layer_sizes=(30, 30, 30), max_iter=1000)

mlp.fit(X_train, y_train)
mlp.score(X_train, y_train)
# Out:
# 0.3953135613915366

# %%
y_pred = mlp.predict(X.iloc[:1991])
y_pred
# Out:
# array([[ 8.44685763, 14.58910245],
#        [ 6.66198661, 14.91580994],
#        [ 5.50948   , 15.12652027],
#        ...,
#        [ 3.22739936,  3.90630935],
#        [ 3.22328849,  3.92381671],
#        [ 3.21915295,  3.94174151]])

# %%
mlp.predict([[9, -35]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# array([[14.3641486 ,  5.68310548]])

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
# x_plot = X['Freq [GHz]'].iloc[:1991]

# %%
# y_plot = y['dB(S(FloquetPort1:1,FloquetPort1:1)) []'].iloc[:1991]

# %%
# y_test['dB(S(FloquetPort1:1,FloquetPort1:1)) []']

# %%
# y_pred = pd.DataFrame(y_pred)

# %%
# x = range(len(y_pred))

# plt.scatter(x_plot, y_plot, label='y_test', marker='x')

# plt.xlabel('Frequency')
# plt.ylabel('S_params')
# plt.legend()

# plt.show()

# %%
# x = range(len(y_pred))

# plt.scatter(x_plot, y_pred[1], label='y_pred', marker='o')

# plt.xlabel('Frequency')
# plt.ylabel('S_params')
# plt.legend()

# plt.show()
